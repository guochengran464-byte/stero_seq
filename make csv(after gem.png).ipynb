# %%
import pandas as pd

samples = [
    ('Y10393D8', 'W202603240063157', '/data/work/liver_hcc_spatial/00_raw/Y10393D8.mRNA(match) 拷贝.png'),
    ('Y40320PC',  'W202603240063121', '/data/work/liver_hcc_spatial/00_raw/Y40320PC.mRNA(match) 拷贝(match).png'),
    ('Y40320ND',  'W202603240063078', '/data/work/liver_hcc_spatial/00_raw/Y40320ND.mRNA(match) 拷贝.png'),
    ('Y10052H8',  'W202603240063031', '/data/work/liver_hcc_spatial/00_raw/Y10052H8.mRNA-恢复的(match) 拷贝.png'),
    ('Y10052E3',  'W202603240062997', '/data/work/liver_hcc_spatial/00_raw/Y10052E3.mRNA(match) 拷贝.png'),
    ('Y10052F1',  'W202603240062964', '/data/work/liver_hcc_spatial/00_raw/Y10052F1.mRNA-恢复的(match) 拷贝.png'),
    ('Y10052H4',  'W202603240062927', '/data/work/liver_hcc_spatial/00_raw/Y10052H4.mRNA(match) 拷贝.png'),
    ('Y01647G5',  'W202603240062892', '/data/work/liver_hcc_spatial/00_raw/Y01647G5.mRNA(match) 拷贝.png'),
    ('Y01647G8',  'W202603240062792', '/data/work/liver_hcc_spatial/00_raw/Y01647G8.mRNA(match) 拷贝.png'),
]

rows = []
for id, wf, ssDNA in samples:
    rows.append({
        'id':              id,
        'ssDNA_path':      ssDNA,
        'gem_path':        f'/data/input/Files/ResultData/Workflow/{wf}/result/{id}.raw.gem',
        'block_size':      13,
        'offset':          0.03,
        'min_dist':        11,
        'expand_distance': 5,
    })

df = pd.DataFrame(rows)
df.to_csv('/data/work/liver_hcc_spatial/segmentation_samples.csv', index=False)
print(df[['id','ssDNA_path']])
# Out:
#          id                                         ssDNA_path
# 0  Y10393D8  /data/work/liver_hcc_spatial/00_raw/Y10393D8.m...
# 1  Y40320PC  /data/work/liver_hcc_spatial/00_raw/Y40320PC.m...
# 2  Y40320ND  /data/work/liver_hcc_spatial/00_raw/Y40320ND.m...
# 3  Y10052H8  /data/work/liver_hcc_spatial/00_raw/Y10052H8.m...
# 4  Y10052E3  /data/work/liver_hcc_spatial/00_raw/Y10052E3.m...
# 5  Y10052F1  /data/work/liver_hcc_spatial/00_raw/Y10052F1.m...
# 6  Y10052H4  /data/work/liver_hcc_spatial/00_raw/Y10052H4.m...
# 7  Y01647G5  /data/work/liver_hcc_spatial/00_raw/Y01647G5.m...
# 8  Y01647G8  /data/work/liver_hcc_spatial/00_raw/Y01647G8.m...
